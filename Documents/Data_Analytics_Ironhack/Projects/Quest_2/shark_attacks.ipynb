# %%
import pandas as pd
# %pip install xlrd

attacks_df = pd.read_excel("GSAF5.xls")
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
attacks_df.head()
# Out:
#                   Date    Year        Type    Country                State  \
# 0  2025-04-19 00:00:00  2025.0  Unprovoked   Maldives  Kulhudhuffushi City
# 1  2025-04-12 00:00:00  2025.0  Unprovoked        USA              Florida
# 2  2025-03-26 00:00:00  2025.0  Unprovoked  Australia                   WA
# 3  2025-03-10 00:00:00  2025.0  Unprovoked  Australia                   WA
# 4  2025-03-07 00:00:00  2025.0  Unprovoked  Australia                  NSW
#
#                                             Location     Activity  \
# 0                                   Haa Dhaalu atoll   snorkeling
# 1  Everglades National Park Flamingo Lodge Highwa...  Undisclosed
# 2          Sandtrax Port Beach North Fremantle Perth     Swimming
# 3                                Duke of Orleans Bay      Surfing
# 4                 Gunyah beach Bundeena Port Hacking     Swimming
#
#                    Name Sex  Age  ...           Species   \
# ...

# %%
attacks_df.describe(["Age", "Time"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 attacks_df.describe(["Age", "Time"])
#
# File c:\Users\sofia\anaconda3\Lib\site-packages\pandas\core\generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)
#   11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)
#   11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# ...

# %%
attacks_df.dtypes
# Out:
# Date               object
# Year              float64
# Type               object
# Country            object
# State              object
# Location           object
# Activity           object
# Name               object
# Sex                object
# Age                object
# Injury             object
# Fatal Y/N          object
# Time               object
# Species            object
# Source             object
# pdf                object
# href formula       object
# href               object
# Case Number        object
# Case Number.1      object
# original order    float64
# Unnamed: 21        object
# Unnamed: 22        object
# dtype: object

# %%
attacks_df.shape
# Out:
# (7012, 23)

# %%
attacks_df['Sex'].describe
# Out:
# <bound method NDFrame.describe of 0        M
# 1        M
# 2        M
# 3        M
# 4       F
#         ..
# 7007     M
# 7008     M
# 7009     M
# 7010     M
# 7011     M
# Name: Sex, Length: 7012, dtype: object>

# %%
unique_values_sex = attacks_df["Sex"].nunique()
print(unique_values_sex)

unique_values_fatal = attacks_df["Fatal Y/N"].unique()
print(unique_values_fatal)

unique_values_time = attacks_df["Time"].unique()
print(unique_values_time)
# Out:
# 10
# ['N' 'Y' 'F' 'M' nan 'n' 'Nq' 'UNKNOWN' 2017 'Y x 2' ' N' 'N ' 'y']
# ['Not stated' '1500hrs' '1430hrs' '1210 hrs' '1340hrs' 'Unknown' '1300hrs'
#  '0815hrs' '1503hrs' '1830hrs' '1645 hrs' '1711hrs' '1600hrs' '1330hrs'
#  '1615hr' '1710hr' '?' '1637hr' 'AM' '16.30hrs' '1600hr' '11.30hr'
#  '1100hr' '1735hr' '11hr15' '16hr15' 'after 1200hr' '1400hr' 15.5 '13h15'
#  '9h' 1300 '14h' '15h30' '13h30' '9h15' 'Not advised' '13h40' '12h30'
#  '16h00' nan '11h30' '06h30' '20h00' '13h00' '11h12' '16h30' '15h00'
#  '02h00' '09h15' 'Early Morning' '16h32' '11h00' 'Morning' '10h30' '13h20'
#  '14h00' '09h00' '10h20' '15h05' '17h00' '15h45' '07h45' '10h40' '07h50'
#  '01h00' '10h00' 'Afternoon' '19h30' 'Evening' '17h50' '09h30' '08h45'
#  '"Midday"' '16h25' '13h55' '13h50' '17h20' '13h45' '10h10' '14h35'
#  'Night' '1500h ' '19h15' '11h20' '07h15' '07h00' '18h00' '08h00' '14h20'
#  '17h30' '07h20' '14h50' '-16h30' '12h00' '17h17' '11h15' '19h00' '07h53'
# ...
